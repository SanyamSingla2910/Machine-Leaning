# %%
#importing 
import numpy as np

# %%
# array uses lesser memory
list1 = range(100)
arr1 = np.arange(100)
# here array will user lesser data

# %%
import sys
print(sys.getsizeof(1)*len(list1))
print(arr1.itemsize*arr1.size)
# Out:
# 2800
# 800

# %%
# checking how numpy arrays are faster 
import time
x = range(100000000)
y = range(100000000)
a= np.arange(100000000)
b= np.arange(100000000)

# %%
start_time = time.time()
c = [(x, y) for x, y in zip(x, y)]
print(time.time()-start_time)
# Out:
# 17.560174465179443

# %%
start_time = time.time()
d = a+b
print(time.time()-start_time)
# Out:
# 0.18676447868347168

# %%
#we did all this to just check that the np arrays are faster than the normal lists
