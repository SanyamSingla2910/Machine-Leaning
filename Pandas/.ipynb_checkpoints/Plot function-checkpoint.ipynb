# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("IPL MATCHES.csv")

# %%
import matplotlib.pyplot as plt
df['winner'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>

# %%
df['toss_decision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# we can create different histograms or any different type of graphs 
df['win_by_runs'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#this is just to visualizze different types of dataframes and create different types of graph
