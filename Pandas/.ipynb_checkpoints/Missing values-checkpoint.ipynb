# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('IPL MATCHES.csv')

# %% [markdown]
# Remove empty values

# %%
df.shape
# Out:
# (636, 18)

# %%
# when all the features will be empty it will drop them
df.dropna(how = 'all').shape
df.dropna(axis = 1).head(1) #removes the collumn where there is any missing value
# Out:
#    id  season        date                team1                        team2  \
# 0   1    2017  2017-04-05  Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                    toss_winner toss_decision  result  dl_applied  win_by_runs  \
# 0  Royal Challengers Bangalore         field  normal           0           35
#
#    win_by_wickets                                      venue
# 0               0  Rajiv Gandhi International Stadium, Uppal

# %%
# in every collumn there was some missing values so entire dataset got empty and only collumns are left 
df.dropna(subset=['win_by_runs'])#to  check only for win by runs collumn
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# Filling duplicates

# %%
# fill every missing value by 0
df.fillna(0).shape #shape is same
# Out:
# (636, 18)

# %%
# to change in do some collumn then
df['umpire3'].fillna('Not Specified',inplace = True)

# %%
df
# we can use bfill and ffill in methor to fill the value before and after the place in the empty place
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
# this data was already decent so we didnt have to make so much changes but it will work in every
# dataset andg help us optimize the data for machine learning
