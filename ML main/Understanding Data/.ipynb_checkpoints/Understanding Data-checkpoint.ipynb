# %%
import pandas as pd

# %%
# importing the data 
df = pd.read_csv('Titanic-Dataset.csv')

# %%
# how big is the data 
df.shape
# Out:
# (891, 12)

# %%
# how does the data looks like 
df.sample(5)
# to get random 5 rows
# Out:
#      PassengerId  Survived  Pclass                         Name     Sex   Age  \
# 746          747         0       3  Abbott, Mr. Rossmore Edward    male  16.0
# 401          402         0       3              Adams, Mr. John    male  26.0
# 405          406         0       2           Gale, Mr. Shadrach    male  34.0
# 560          561         0       3     Morrow, Mr. Thomas Rowan    male   NaN
# 128          129         1       3            Peter, Miss. Anna  female   NaN
#
#      SibSp  Parch     Ticket     Fare  Cabin Embarked
# 746      1      1  C.A. 2673  20.2500    NaN        S
# 401      0      0     341826   8.0500    NaN        S
# 405      1      0      28664  21.0000    NaN        S
# 560      0      0     372622   7.7500    NaN        Q
# 128      1      1       2668  22.3583  F E69        C

# %%
# to check what are the data types of the columns 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# are there any missing values 
df.isnull().sum()
# to get how many missing values we have
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# understanding mathematically 
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# checking if duplicate values are there or not 
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# what is correlation between the collumns 
df.corr(numeric_only=True)['Survived']
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64

# %%
# these are just the first things we check to analyze our data
