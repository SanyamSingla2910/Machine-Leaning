# %%
import numpy as np 
import pickle

# %%
Model = pickle.load(open('Model With Pipeline.pkl','rb'))

# %%
test_input = np.array([1,'male',18.0,0,0,10.5,'S']).reshape(1,7)
test_input
# Out:
# array([['1', 'male', '18.0', '0', '0', '10.5', 'S']], dtype='<U32')

# %%
Model.predict(test_input)
# Out:
# C:\Users\singl\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\Users\singl\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])

# %%
# it made our work a lot easier
