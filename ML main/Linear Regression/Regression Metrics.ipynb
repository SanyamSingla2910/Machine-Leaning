# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
sns.scatterplot(x=df['cgpa'],y=df['package'])
plt.show()

# %%
# making input and output 
x=df.iloc[:,0:1]
y=pd.DataFrame(df.iloc[:,1])

# %%
# main imports 
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
x_train , x_test , y_train , y_test =train_test_split(x,y,test_size=0.25,random_state=50)

# %%
lr = LinearRegression()

lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
r2_score(y_test,lr.predict(x_test))
# Out:
# 0.811475355431068

# %%
# to see the regression line 
sns.scatterplot(x=df['cgpa'],y=df['package'])
plt.plot(x_test,lr.predict(x_test),color = 'red')
plt.show()

# %%
# slope of the line 
lr.coef_
# Out:
# array([[0.56826736]])

# %%
# intercept 
lr.intercept_
# Out:
# array([-0.99153783])

# %%
# Now printing metrics 
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,root_mean_squared_error

# %%
pred = lr.predict(x_test)

# %%
# printing the regression metrics 
print('MSE',mean_squared_error(y_test,pred))
print('MAE',mean_absolute_error(y_test,pred))
print('RMSE',root_mean_squared_error(y_test,pred))
print('R2',r2_score(y_test,pred))
r2 = r2_score(y_test,pred)
# Out:
# MSE 0.0772693216428709
# MAE 0.2205964210014983
# RMSE 0.277973598823469
# R2 0.811475355431068
# 0.811475355431068

# %%
# adjusted r2
print(1-((1-r2)*(pred.shape[0]-1))/(pred.shape[0]-1-1))
# Out:
# 0.8075477586692152
