# %%
import pandas as pd
import requests

# %%
# i am fething genres of movies from API of watchmode.com 
data = requests.get('https://api.watchmode.com/v1/genres/?apiKey=Gv6A5xOxZcjI21EhKaMBGTTrMK20IyhevxHASHlS')
type(data)
# Out:
# requests.models.Response

# %%
data = data.json()

# %%
pd.DataFrame(data)
#  i only want name of the generes so what i can do is 
genre = pd.DataFrame(data)[['name']]
genre
# Out:
#                   name
# 0               Action
# 1   Action & Adventure
# 2                Adult
# 3            Adventure
# 4            Animation
# 5                Anime
# 6            Biography
# 7               Comedy
# 8                Crime
# 9          Documentary
# 10               Drama
# 11              Family
# 12             Fantasy
# 13                Food
# 14           Game Show
# 15             History
# 16              Horror
# 17                Kids
# 18               Music
# 19             Musical
# 20             Mystery
# 21              Nature
# 22                News
# 23             Reality
# 24             Romance
# 25    Sci-Fi & Fantasy
# 26     Science Fiction
# 27                Soap
# 28              Sports
# 29        Supernatural
# 30                Talk
# 31            Thriller
# 32              Travel
# 33            TV Movie
# 34                 War
# 35      War & Politics
# 36             Western

# %%
# now exapmle i need data of bradd pitt from that api 
brad = requests.get('https://api.watchmode.com/v1/person/7110004?apiKey=Gv6A5xOxZcjI21EhKaMBGTTrMK20IyhevxHASHlS')

# %%
df = pd.DataFrame(brad.json())

# %%
df
# Out:
#         id  full_name first_name last_name  tmdb_id    imdb_id  \
# 0  7110004  Brad Pitt       Brad      Pitt      287  nm0000093
# 1  7110004  Brad Pitt       Brad      Pitt      287  nm0000093
# 2  7110004  Brad Pitt       Brad      Pitt      287  nm0000093
# 3  7110004  Brad Pitt       Brad      Pitt      287  nm0000093
#
#   main_profession secondary_profession tertiary_profession date_of_birth  \
# 0           actor           soundtrack            producer    1963-12-18
# 1           actor           soundtrack            producer    1963-12-18
# 2           actor           soundtrack            producer    1963-12-18
# 3           actor           soundtrack            producer    1963-12-18
#
#   date_of_death          place_of_birth gender  known_for  \
# 0          None  Shawnee, Oklahoma, USA      m    1132806
# 1          None  Shawnee, Oklahoma, USA      m    1183315
# 2          None  Shawnee, Oklahoma, USA      m    1336708
# 3          None  Shawnee, Oklahoma, USA      m    1387087
#
#    relevance_percentile
# 0                   100
# 1                   100
# 2                   100
# 3                   100

# %%
# i got info about him 
# now i want to fetch titles from the api
titles = requests.get('https://api.watchmode.com/v1/list-titles/?apiKey=Gv6A5xOxZcjI21EhKaMBGTTrMK20IyhevxHASHlS')
pd.DataFrame(titles.json()['titles'])
# Out:
#           id                      title  year     imdb_id  tmdb_id tmdb_type  \
# 0    3250797                       Rafa  2026  tt35052852   279884        tv
# 1    3174840            Clarkson's Farm  2021  tt10541088   117648        tv
# 2    3178664  The Legend of Vox Machina  2022  tt11247158   135934        tv
# 3    3224329           Murder Mindfully  2024  tt30217222   252372        tv
# 4    3169127            Sweet Magnolias  2020   tt9077540   102904        tv
# ..       ...                        ...   ...         ...      ...       ...
# 245   544066           Agatha All Along  2024  tt15571732   138501        tv
# 246  3239271    The Other Bennet Sister  2026  tt37022512   273866        tv
# 247  3225800       When the Phone Rings  2024  tt33503491   253905        tv
# 248  3220779                      Stick  2025  tt31710249   248830        tv
# 249  3212158                   Dandadan  2024  tt30217403   240411        tv
#
#               type
# 0    tv_miniseries
# 1        tv_series
# 2        tv_series
# 3        tv_series
# 4        tv_series
# ..             ...
# 245  tv_miniseries
# 246      tv_series
# 247      tv_series
# 248      tv_series
# 249      tv_series
#
# [250 rows x 7 columns]

# %% [markdown]
# # Fetching data from a new api url

# %%
url = "https://cricbuzz-cricket.p.rapidapi.com/mcenter/v1/40381/hscard"

headers = {
	"x-rapidapi-key": "bdca34d3d6mshd37bc0156f99f2dp1e81aajsnc53c2acd03a9",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.get(url, headers=headers)

response = (response.json()['scorecard'])
pd.DataFrame(response)
# Out:
#    inningsid                                            batsman  \
# 0          1  [{'id': 1114, 'balls': 5, 'runs': 5, 'fours': ...
# 1          2  [{'id': 22891, 'balls': 23, 'runs': 16, 'fours...
#
#                                               bowler  \
# 0  [{'id': 15475, 'overs': '4', 'maidens': 0, 'wi...
# 1  [{'id': 10449, 'overs': '4', 'maidens': 0, 'wi...
#
#                                                  fow  \
# 0  {'fow': [{'batsmanid': 1114, 'batsmanname': 'S...
# 1  {'fow': [{'batsmanid': 22896, 'batsmanname': '...
#
#                                               extras  score  wickets  overs  \
# 0  {'legbyes': 1, 'byes': 0, 'wides': 5, 'noballs...    150       10   18.5
# 1  {'legbyes': 4, 'byes': 1, 'wides': 6, 'noballs...    141        7   20.0
#
#    runrate    batteamname batteamsname  isdeclared  isfollowon  ballnbr   rpb  \
# 0     7.96        Ireland          IRE       False       False      113  1.33
# 1     7.05  United States          USA       False       False      120  1.18
#
#                                          partnership
# 0  {'partnership': [{'id': 0, 'bat1id': 1114, 'ba...
# 1  {'partnership': [{'id': 0, 'bat1id': 22891, 'b...

# %% [markdown]
# # Another API just for practice Student Data

# %%
response = requests.get('https://dummyjson.com/users')

# %%
pd.DataFrame(response.json()['users'])
# Out:
#     id  firstName   lastName maidenName  age  gender  \
# 0    1      Emily    Johnson      Smith   29  female
# 1    2    Michael   Williams              36    male
# 2    3     Sophia      Brown              43  female
# 3    4      James      Davis              46    male
# 4    5       Emma     Miller    Johnson   31  female
# 5    6     Olivia     Wilson              23  female
# 6    7  Alexander      Jones              39    male
# 7    8        Ava     Taylor              28  female
# 8    9      Ethan   Martinez              34    male
# 9   10   Isabella   Anderson      Davis   32  female
# 10  11       Liam     Garcia              30    male
# 11  12        Mia  Rodriguez              25  female
# 12  13       Noah  Hernandez              41    male
# 13  14  Charlotte      Lopez   Martinez   37  female
# 14  15    William   Gonzalez              33    male
# 15  16      Avery      Perez              26  female
# 16  17     Evelyn    Sanchez              38  female
# 17  18      Logan     Torres              32    male
# 18  19    Abigail     Rivera              29  female
# 19  20    Jackson      Evans              35    male
# 20  21    Madison    Collins              27  female
# 21  22     Elijah    Stewart              34    male
# 22  23      Chloe    Morales              40  female
# 23  24      Mateo     Nguyen              31    male
# 24  25     Harper      Kelly      Evans   28  female
# 25  26     Evelyn   Gonzalez              36  female
# 26  27     Daniel       Cook              42    male
# 27  28       Lily        Lee      Brown   30  female
# 28  29      Henry       Hill              39    male
# 29  30    Addison     Wright              33  female
#
#                                 email             phone    username  \
# 0       emily.johnson@x.dummyjson.com  +81 965-431-3024      emilys
# 1    michael.williams@x.dummyjson.com  +49 258-627-6644    michaelw
# 2        sophia.brown@x.dummyjson.com  +81 210-652-2785     sophiab
# 3         james.davis@x.dummyjson.com  +49 614-958-9364      jamesd
# 4         emma.miller@x.dummyjson.com  +91 759-776-1614       emmaj
# 5       olivia.wilson@x.dummyjson.com  +91 607-295-6448     oliviaw
# 6     alexander.jones@x.dummyjson.com  +61 260-824-4986  alexanderj
# 7          ava.taylor@x.dummyjson.com   +1 458-853-7877        avat
# 8      ethan.martinez@x.dummyjson.com  +92 933-608-5081      ethanm
# 9   isabella.anderson@x.dummyjson.com  +49 770-658-4885   isabellad
# 10        liam.garcia@x.dummyjson.com  +92 870-217-6201       liamg
# 11      mia.rodriguez@x.dummyjson.com  +49 989-461-8403        miar
# 12     noah.hernandez@x.dummyjson.com  +49 393-605-6968       noahh
# 13    charlotte.lopez@x.dummyjson.com  +44 373-953-5028  charlottem
# 14   william.gonzalez@x.dummyjson.com  +81 905-252-7319    williamg
# 15        avery.perez@x.dummyjson.com  +61 731-431-3457      averyp
# 16     evelyn.sanchez@x.dummyjson.com   +1 623-880-6871     evelyns
# 17       logan.torres@x.dummyjson.com  +81 507-434-8733      logant
# 18     abigail.rivera@x.dummyjson.com  +91 228-363-7806    abigailr
# 19      jackson.evans@x.dummyjson.com  +44 468-628-6686    jacksone
# 20    madison.collins@x.dummyjson.com  +81 259-957-5711    madisonc
# 21     elijah.stewart@x.dummyjson.com  +44 468-357-7872     elijahs
# 22      chloe.morales@x.dummyjson.com  +92 468-541-7133      chloem
# 23       mateo.nguyen@x.dummyjson.com   +1 341-597-6694      mateon
# 24       harper.kelly@x.dummyjson.com  +92 518-863-2863     harpere
# 25    evelyn.gonzalez@x.dummyjson.com  +61 708-508-4638     evelyng
# 26        daniel.cook@x.dummyjson.com  +44 254-761-6843     danielc
# 27           lily.lee@x.dummyjson.com   +1 808-757-9867       lilyb
# 28         henry.hill@x.dummyjson.com   +1 240-833-4680      henryh
# 29     addison.wright@x.dummyjson.com   +1 514-384-3300    addisonw
#
#           password  ...                                            address  \
# 0       emilyspass  ...  {'address': '626 Main Street', 'city': 'Phoeni...
# 1     michaelwpass  ...  {'address': '385 Fifth Street', 'city': 'Houst...
# 2      sophiabpass  ...  {'address': '1642 Ninth Street', 'city': 'Wash...
# 3       jamesdpass  ...  {'address': '238 Jefferson Street', 'city': 'S...
# 4        emmajpass  ...  {'address': '607 Fourth Street', 'city': 'Jack...
# 5      oliviawpass  ...  {'address': '547 First Street', 'city': 'Fort ...
# 6   alexanderjpass  ...  {'address': '664 Maple Street', 'city': 'India...
# 7         avatpass  ...  {'address': '1197 First Street', 'city': 'Fort...
# 8       ethanmpass  ...  {'address': '466 Pine Street', 'city': 'San An...
# 9    isabelladpass  ...  {'address': '1964 Oak Street', 'city': 'New Yo...
# 10       liamgpass  ...  {'address': '576 Fifth Street', 'city': 'Denve...
# 11        miarpass  ...  {'address': '1627 Sixth Street', 'city': 'Jack...
# 12       noahhpass  ...  {'address': '1413 Maple Street', 'city': 'New ...
# 13  charlottempass  ...  {'address': '208 Second Street', 'city': 'Colu...
# 14    williamgpass  ...  {'address': '31 Maple Street', 'city': 'San Jo...
# 15      averyppass  ...  {'address': '1125 First Street', 'city': 'Colu...
# 16     evelynspass  ...  {'address': '1170 Lincoln Street', 'city': 'Sa...
# 17      logantpass  ...  {'address': '907 Seventh Street', 'city': 'Col...
# 18    abigailrpass  ...  {'address': '996 Oak Street', 'city': 'Chicago...
# 19    jacksonepass  ...  {'address': '1873 Main Street', 'city': 'New Y...
# 20    madisoncpass  ...  {'address': '1892 Lincoln Street', 'city': 'Ph...
# 21     elijahspass  ...  {'address': '1701 Eighth Street', 'city': 'Col...
# 22      chloempass  ...  {'address': '401 Fourth Street', 'city': 'Dall...
# 23      mateonpass  ...  {'address': '1578 Fourth Street', 'city': 'Col...
# 24     harperepass  ...  {'address': '1591 Adams Street', 'city': 'Phil...
# 25     evelyngpass  ...  {'address': '1065 Lincoln Street', 'city': 'Da...
# 26     danielcpass  ...  {'address': '1163 Pine Street', 'city': 'Los A...
# 27       lilybpass  ...  {'address': '1946 Oak Street', 'city': 'Phoeni...
# 28      henryhpass  ...  {'address': '1837 Maple Street', 'city': 'Indi...
# 29    addisonwpass  ...  {'address': '568 Tenth Street', 'city': 'San F...
#
#            macAddress                                    university  \
# 0   47:fa:41:18:ec:eb              University of Wisconsin--Madison
# 1   79:15:78:99:60:aa                         Ohio State University
# 2   12:a3:d3:6f:5c:5b                         Pepperdine University
# 3   10:7d:df:1f:97:58             University of Southern California
# 4   32:b9:7e:8d:f5:e8                       Northeastern University
# 5   9c:7f:ea:34:18:19     University of North Carolina--Chapel Hill
# 6   d2:64:58:2d:1c:46      University of Illinois--Urbana-Champaign
# 7   8d:2e:c2:d6:e7:a8              University of Wisconsin--Madison
# 8    59:e:9e:e3:29:da                           Syracuse University
# 9   b1:b0:d0:a2:82:80  California Institute of Technology (Caltech)
# 10  31:9a:28:8b:99:6c                         Ohio State University
# 11   53:d7:a4:6:1e:58                                William & Mary
# 12  d4:fe:ae:8f:eb:a3                     New York University (NYU)
# 13  f6:ff:37:aa:6c:f1                       Northeastern University
# 14  f5:68:28:f9:ec:89                              Tufts University
# 15  b3:ff:f3:c5:37:46                            Harvard University
# 16  f8:e5:bd:43:bc:d8            Washington University in St. Louis
# 17    40:d:5c:1:7d:bf      University of Illinois--Urbana-Champaign
# 18  1d:a6:58:2a:e5:e4  California Institute of Technology (Caltech)
# 19   81:14:1:97:88:85                         Ohio State University
# 20  13:b0:d0:23:4d:26                    University of Pennsylvania
# 21  75:17:c6:35:fc:6d                         Georgetown University
# 22   fc:f:29:e1:37:b8                           Syracuse University
# 23  a7:26:10:7a:36:29                           Columbia University
# 24   b:ff:33:67:94:e4                                Boston College
# 25  89:5e:5a:2a:72:42            Washington University in St. Louis
# 26  6e:73:dc:3a:85:10                           Columbia University
# 27   18:b6:c7:a:50:3f                      Johns Hopkins University
# 28  fa:c3:1b:21:5f:44      University of Illinois--Urbana-Champaign
# 29    fb:0:94:21:16:c                           Syracuse University
#
#                                                  bank  \
# 0   {'cardExpire': '05/28', 'cardNumber': '3693233...
# 1   {'cardExpire': '01/30', 'cardNumber': '3530633...
# 2   {'cardExpire': '10/27', 'cardNumber': '6011212...
# 3   {'cardExpire': '07/30', 'cardNumber': '5303440...
# 4   {'cardExpire': '07/30', 'cardNumber': '5237188...
# 5   {'cardExpire': '06/30', 'cardNumber': '3763200...
# 6   {'cardExpire': '12/29', 'cardNumber': '5189302...
# 7   {'cardExpire': '08/30', 'cardNumber': '5349974...
# 8   {'cardExpire': '10/27', 'cardNumber': '3598603...
# 9   {'cardExpire': '03/30', 'cardNumber': '3602093...
# 10  {'cardExpire': '12/29', 'cardNumber': '3614993...
# 11  {'cardExpire': '02/29', 'cardNumber': '3439323...
# 12  {'cardExpire': '03/30', 'cardNumber': '6262462...
# 13  {'cardExpire': '12/27', 'cardNumber': '3634388...
# 14  {'cardExpire': '05/30', 'cardNumber': '6228256...
# 15  {'cardExpire': '08/29', 'cardNumber': '3780240...
# 16  {'cardExpire': '01/29', 'cardNumber': '3514443...
# 17  {'cardExpire': '04/30', 'cardNumber': '6258651...
# 18  {'cardExpire': '01/27', 'cardNumber': '6011399...
# 19  {'cardExpire': '07/30', 'cardNumber': '3767606...
# 20  {'cardExpire': '09/27', 'cardNumber': '5551259...
# 21  {'cardExpire': '05/28', 'cardNumber': '3648138...
# 22  {'cardExpire': '09/30', 'cardNumber': '3470362...
# 23  {'cardExpire': '12/29', 'cardNumber': '4021840...
# 24  {'cardExpire': '06/27', 'cardNumber': '4488823...
# 25  {'cardExpire': '08/28', 'cardNumber': '6011735...
# 26  {'cardExpire': '05/29', 'cardNumber': '5485409...
# 27  {'cardExpire': '12/28', 'cardNumber': '5551782...
# 28  {'cardExpire': '11/29', 'cardNumber': '3625097...
# 29  {'cardExpire': '06/28', 'cardNumber': '5274971...
#
#                                               company      ein          ssn  \
# 0   {'department': 'Engineering', 'name': 'Dooley,...  977-175  900-590-289
# 1   {'department': 'Support', 'name': 'Spinka - Di...  912-602  108-953-962
# 2   {'department': 'Research and Development', 'na...  963-113  638-461-822
# 3   {'department': 'Support', 'name': 'Pagac and S...  904-810  116-951-314
# 4   {'department': 'Human Resources', 'name': 'Gra...  403-505  526-210-885
# 5   {'department': 'Product Management', 'name': '...  921-709  836-772-168
# 6   {'department': 'Engineering', 'name': 'Dickens...  638-127  722-993-925
# 7   {'department': 'Marketing', 'name': 'Nikolaus ...  297-762  257-419-109
# 8   {'department': 'Support', 'name': 'Gorczany - ...  790-434  569-650-348
# 9   {'department': 'Marketing', 'name': 'Pollich -...  127-297  902-438-728
# 10  {'department': 'Services', 'name': 'Considine ...  326-604  933-784-949
# 11  {'department': 'Accounting', 'name': 'Miller, ...  754-660  749-524-124
# 12  {'department': 'Engineering', 'name': 'Botsfor...  877-628  660-847-389
# 13  {'department': 'Accounting', 'name': 'Zulauf a...  364-782  255-491-479
# 14  {'department': 'Marketing', 'name': 'Spinka - ...  830-515  690-544-755
# 15  {'department': 'Accounting', 'name': 'Herzog I...  348-493  679-523-686
# 16  {'department': 'Support', 'name': 'Predovic - ...  604-817  689-332-644
# 17  {'department': 'Training', 'name': 'Jast - Nad...  576-218  806-639-934
# 18  {'department': 'Human Resources', 'name': 'Pro...  173-637  655-823-929
# 19  {'department': 'Legal', 'name': 'Kuhlman LLC',...  843-260  248-787-886
# 20  {'department': 'Engineering', 'name': 'Mayer -...  716-166  457-258-950
# 21  {'department': 'Legal', 'name': 'Langworth Gro...  520-394  287-380-801
# 22  {'department': 'Sales', 'name': 'Grady LLC', '...  913-597  938-883-163
# 23  {'department': 'Accounting', 'name': 'Spinka L...  229-249  416-877-230
# 24  {'department': 'Legal', 'name': 'Leffler, Rolf...  592-557  209-544-548
# 25  {'department': 'Accounting', 'name': 'Tromp, G...  569-275  487-680-127
# 26  {'department': 'Support', 'name': 'Morissette,...  585-905  645-515-583
# 27  {'department': 'Product Management', 'name': '...  229-776  358-185-671
# 28  {'department': 'Services', 'name': 'Gerlach, F...  118-957  925-686-100
# 29  {'department': 'Services', 'name': 'Kreiger In...  415-286  804-492-390
#
#                                             userAgent  \
# 0   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 1   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 2   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 4   Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:9...
# 5   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 6   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 7   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 8   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 9   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 10  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 11  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 12  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 13  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 14  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 15  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 16  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 17  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 18  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 19  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 20  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 21  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 22  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 23  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 24  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
# 25  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 26  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:9...
# 27  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 28  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 29  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
#
#                                                crypto       role
# 0   {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...      admin
# 1   {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...      admin
# 2   {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...      admin
# 3   {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...      admin
# 4   {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...      admin
# 5   {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...  moderator
# 6   {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...  moderator
# 7   {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...  moderator
# 8   {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...  moderator
# 9   {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...  moderator
# 10  {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...  moderator
# 11  {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...  moderator
# 12  {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...  moderator
# 13  {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...  moderator
# 14  {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...  moderator
# 15  {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...       user
# 16  {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...       user
# 17  {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...       user
# 18  {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...       user
# 19  {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...       user
# 20  {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...       user
# 21  {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...       user
# 22  {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...       user
# 23  {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...       user
# 24  {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...       user
# 25  {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...       user
# 26  {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...       user
# 27  {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...       user
# 28  {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...       user
# 29  {'coin': 'Bitcoin', 'wallet': '0xb9fc2fe63b2a6...       user
#
# [30 rows x 28 columns]

# %%
# this is just to get some real world data because when we will be going to make projects then real world data is very important
