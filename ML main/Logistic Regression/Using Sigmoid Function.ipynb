# %%
import pandas as pd 
import numpy as np 
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt 
import seaborn as sns
x, y = make_classification(n_samples=100, n_features=2, n_informative=1,n_redundant=0,
                           n_classes=2, n_clusters_per_class=1, random_state=41,hypercube=False,class_sep=50)

# %%
sns.scatterplot(x=x[:,0],y=x[:,1],hue=y)
plt.title('Data')
plt.show()

# %%
def Model(x,y):
    x = np.insert(x,0,1,axis=1)
    weights = np.ones(x.shape[1])
    lr = 0.1

    for i in range (1000000):
        j = np.random.randint(0,x.shape[0])
        y_hat = step(np.dot(x[j],weights))
        weights = weights + lr*(y[j]-y_hat)*x[j]
    return weights[0],weights[1:]

# %%
def step(z):
    return 1/(1+np.exp(-z))

# %%
intercept_ , coef_ = Model(x,y)

# %%
print(intercept_,coef_)
# Out:
# 5.366849273974001 [5.35826232 0.27652747]

# %%
m2 = -(coef_[0]/coef_[1])
b2 = -(intercept_/coef_[1])

# %%
m1 = -(coef_[0]/coef_[1])
b1 = -(intercept_/coef_[1])

# %%
# Plotting the line 
x_input = np.linspace(-5,5,10)
y_input = m1*x_input + b1
y2_input = m2*x_input + b2
sns.scatterplot(x=x[:,0],y=x[:,1],hue=y)
plt.plot(x_input,y2_input,color='black')
plt.plot(x_input,y_input,color = 'red')
# We make the regression line now 
plt.ylim(-4,4)
# Out:
# (-4.0, 4.0)

# %%
# Done using Sigmoid function but it is still not the most optimal fit line that sklearn is using
