# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('titanic_toy.csv',usecols=['Age','Fare','Survived'])

# %%
df.head()
# Out:
#     Age     Fare  Survived
# 0  22.0   7.2500         0
# 1  38.0  71.2833         1
# 2  26.0   7.9250         1
# 3  35.0  53.1000         1
# 4  35.0   8.0500         0

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import MissingIndicator

# %%
x_train , x_test , y_train , y_test = train_test_split(df.iloc[:,0:2],df['Survived'],test_size=0.2,random_state=245)

# %%
mis = MissingIndicator()
x_train.head()
# Out:
#       Age     Fare
# 19    NaN   7.2250
# 274   NaN   7.7500
# 475   NaN  52.0000
# 598   NaN   7.2250
# 833  23.0   7.8542

# %%
x_train_age = mis.fit_transform(x_train.iloc[:,0:1])

# %%
x_test_age = mis.transform(x_test.iloc[:,0:1])

# %%
x_train['age indicator'] = x_train_age

# %%
x_test['age indicator'] = x_test_age

# %%
x_train.head()
# Out:
#       Age     Fare  age indicator
# 19    NaN   7.2250           True
# 274   NaN   7.7500           True
# 475   NaN  52.0000           True
# 598   NaN   7.2250           True
# 833  23.0   7.8542          False

# %%
 # we will do automatic parameter finding when we will start learning models
