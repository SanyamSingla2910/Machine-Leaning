# %%
import pandas as pd 
import numpy as np
from sklearn.datasets import make_regression

# %%
x,y = make_regression(n_samples=4,n_features=1,n_targets=1,noise=80,n_informative=1,random_state=50)

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
plt.scatter(x,y)

# %%
# applying ols
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([68.56953237])

# %%
# slope came as 68.56953237
# intercept is 
lr.intercept_
# Out:
# np.float64(10.844459287464261)

# %%
# Now applying Gradient Descent as m=68.56953237
# firstly taking b as 
pred = x*68.56953237 + b

# %%
plt.scatter(x,y)
plt.plot(x,pred,color="red")
plt.plot(x,lr.predict(x),color='yellow')

# %%
# We need to get close to that yellow line 
m=68.56953237
b=0

# %%
# keeping learning rate
n=0.01

# %%
# finding the slope using the folmula
slope = -2 * np.sum(y-m*x-b)
slope
# Out:
# np.float64(-347.02269710448365)

# %%
b = b - n*slope

# %%
# new b
b
# Out:
# np.float64(3.470226971044837)

# %%
# now ploting the graph again 
plt.scatter(x,y)
plt.plot(x,pred,color="red")
plt.plot(x,lr.predict(x),color='yellow')

# %%
# we can see line moved closer 
# Iteration(epoch)2
slope = -2 * np.sum(y-m*x-b)
b = b - n*slope
b
# Out:
# np.float64(5.829981311355326)

# %%
# iteration 3
slope = -2 * np.sum(y-m*x-b)
b = b - n*slope
b
# Out:
# np.float64(7.434614262766459)

# %%
# iteration 4 
slope = -2 * np.sum(y-m*x-b)
b = b - n*slope
b
# Out:
# np.float64(8.52576466972603)

# %%
# iteration 5
slope = -2 * np.sum(y-m*x-b)
b = b - n*slope
b
# Out:
# np.float64(9.267746946458537)

# %%
# iteration 6 
slope = -2 * np.sum(y-m*x-b)
b = b - n*slope
b
# Out:
# np.float64(9.77229489463664)

# %%
# iteration 7
slope = -2 * np.sum(y-m*x-b)
b = b - n*slope
b
# Out:
# np.float64(10.115387499397752)

# %%
# iteration 8 
slope = -2 * np.sum(y-m*x-b)
b = b - n*slope
b
# Out:
# np.float64(10.348690470635308)

# %%
# iteration 9
slope = -2 * np.sum(y-m*x-b)
b = b - n*slope
b
# Out:
# np.float64(10.507336491076845)

# %%
# iteration 10
slope = -2 * np.sum(y-m*x-b)
b = b - n*slope
b
# Out:
# np.float64(10.615215784977092)

# %%
# now making the line again 
# now ploting the graph again 
plt.scatter(x,y)
plt.plot(x,pred,color="red")
plt.plot(x,lr.predict(x),color='yellow')

# %%
# We can see we almost merged those two lines 
# making a loop now 
b = 100
m=68.56953237
epochs = 20

for i in range (epochs):
    slope = -2 * np.sum(y-m*x-b)
    b = b - 0.01*slope
    print(b)
# Out:
# 71.47022697104484
# 52.06998131135533
# 38.877814262766464
# 29.907140669726033
# 23.807082626458538
# 19.659043157036642
# 16.838376317829752
# 14.920322867169068
# 13.616046520719804
# 12.729138605134303
# 12.126041222536163
# 11.715935002369427
# 11.437062772656047
# 11.247429656450947
# 11.11847913743148
# 11.030792784498244
# 10.971166064503644
# 10.930619894907313
# 10.903048499581809
# 10.884299950760466
